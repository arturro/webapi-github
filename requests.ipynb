# %%
import requests
from pprint import pprint, pformat

# %%
url = "https://onet.pl/"
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <meta charset="utf-8" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><script>/* <![CDATA[ */ ringDataLayer = {"context":{"variant":{"accelerator":"d3d3Lm9uZXQucGw6OkJQUk9EXzNfMF9SRVNU"},"publication_structure":{"root":"WWW_ONET_PL"},"id":{"aureus_offers":["ezypwtiitp","r0cqftpysw","cvzewpvvkh","nuhnfucl2d","tnqixzbwm6","iq1dgj2lqe","dmpxutgsgd","va2waefj68","ub10brahel","trm2rkpgfy","yf0uxftf77","e3zjcvav9p","0t5awvrbfz","zapcqxovbx","tre1l71ypd","tpvh2mbxsy","drlhsxvxac"]}},"content":{"object":{"type":"list"},"part":1,"source":{"system":"ring_content_space","id":"a17e9bfd-e62d-4ed5-9041-0365fd2eefeb"}}}; /* ]]> */</script><script>/* <![CDATA[ */ accConf = {"rum":{"tid":"EA-1746213","boot":"disable","cookieInfo":0,"pageType":"HTML"},"events":{"endpointPaths":["/a8f4d8cd95e164917035b64b867a45dd"]}}; /* ]]> */</script>\n        <meta name="msapplication-starturl" content="https://www.onet.pl/"/>\n        <meta name="description" content="Onet: codzienne źródło informacji milionów Polaków - wiadomości z kraju i ze świata 24/7, pogoda, sport, biznes, moto, rozrywka. Bądź na bieżąco z Onet!"/>\n        <meta property="og:url" content="https://www.onet.pl/"/>\n        <meta property="og:title" content="Onet – Jesteś na bieżąco "/>\n        <meta property="og:description" content="Onet: codzienne źródło informacji milionów Polaków - wiadomości z kraju i ze świata 24/7, pogoda, sport, biznes, moto, rozrywka. Bądź na bieżąco z Onet!"/>\n        <meta property="og:image" content="https://ocdn.eu/images/pulscms/OWU7MDA_/20ec3038d7c7d1637e04da3395de954d.png">\n        <meta property="og:type" content="website" />\n        <meta property="fb:app_id" content="226508470737473"/>\n        \n        <meta name="referrer" content="origin">\n        <meta name="viewport" content="width=1280">\n        <title>Onet – Jesteś na bieżąco </title>\n        \n        <link rel="manifest" href="/v2/manifest.json" />\n        <link rel="canonical" href="https://www.onet.pl" />\n        \n        <link rel="dns-prefetch" href="https://ocdn.eu" />\n        <link rel="dns-prefetch" href="https://lib.onet.pl" />\n        <link rel="dns-prefetch" href="https://csr.onet.pl" />\n        <link rel="dns-prefetch" href="https://kropka.onet.pl" />\n        <link rel="dns-prefetch" href="https://google-analytics.com" />\n        <link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net" />\n        <link rel="dns-prefetch" href="https://fonts.googleapis.com" />\n        <link rel="dns-prefetch" href="https://fonts.gstatic.com" />\n        <link rel="dns-prefetch" href="https://phx.onet.pl" />\n        <link rel="icon" type="image/png" href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/favicon-16x16.png" sizes="16x16">\n        <link rel="icon" type="image/png" href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/favicon-32x32.png" sizes="32x32">\n        <link rel="icon" type="image/png" href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/pwa-192x192.png" sizes="192x192">\n        <link rel="apple-touch-icon" href="https://ocdn.eu/onetmobilemainpage/manifestprod/icons2/pwa-192x192_ios.png" sizes="192x192">\n\n        <style type="text/css">\n            @font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:400;src:local("Fira Sans Regular"),local("FiraSans-Regular"),url(https://ocdn.eu/onetmobilemainpage/firafonts/p05/FiraSans-Regular.woff) format("woff")}@font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:500;src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://ocdn.eu/onetmobilemainpage/firafonts/p05/FiraSans-Medium.woff) format("woff")}@font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:700;src:local("Fira Sans Bold"),local("FiraSans-Bold"),url(https://ocdn.eu/onetmobilemainpage/firafonts/p05/FiraSans-Bold.woff) format("woff")}@font-face{font-family:\'onetsg\';src:url(https://ocdn.eu/onetmobilem ...

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '172554', 'Connection': 'keep-alive', 'Server': 'Ring Publishing - Accelerator', 'Date': 'Wed, 03 Nov 2021 18:38:28 GMT', 'Vary': 'Accept-Encoding, user-agent', 'content-encoding': 'gzip', 'set-cookie': 'aureus-cache-key-onet-film=1747422596; domain=www.onet.pl; Max-Age=3599; Expires=Wed, 03-Nov-2021 19:38:27 GMT, aureus-browser-cache="86eNxjWyId5uc8wMi0Lz3Jepu0DLdMYN/smweXV5HCCIkqLH5vu+ScFXNyB3tVByu8rIwo9TtaoD7kLV11xDeHBQfPt2vqvHKR6sW8uFoZpmMyy7wPcNzTL5pFYfqilP2YM0fjxr8IWN+7sNIyx5IQ=="; Version=1; Domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-oferty2=-1314043481; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-oferty3=1218670026; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-podroze=-2101885636; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-sport_gql=-170008283; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-moto=-346568912; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-noizz=1660533013; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-gamesonline=600672838; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-breakingNews=-1556444008; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-biznes=-932536936; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-technologie=1494516036; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-vod=-1542607624; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-inspiracje=-1381637078; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-paid_promo=-1700698976; domain=www.onet.pl; Max-Age=3599; Expires=Wed, 03-Nov-2021 19:38:27 GMT, aureus-cache-key-onet-wiadomosci_gql=769283373; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-lamoda=-1494515482; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-impnews=1566437523; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, acc_segment=41; Path=/; Max-Age=604800; Secure', 'cache-control': 'no-cache', 'link': '<https://ocdn.eu>; rel=preconnect, <https://events.ocdn.eu>; rel=preconnect', 'etag': '"172554-7ac9154c187164f1"', 'x-dns-prefetch-control': 'off', 'x-frame-options': 'SAMEORIGIN', 'strict-transport-security': 'max-age=0', 'x-download-options': 'noopen', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'content-security-policy-report-only': 'block-all-mixed-content; report-uri https://events.ocdn.eu/v2/csp-report?_ac=events&_fv=www.onet.pl::BPROD_3_0_REST', 'access-control-allow-origin': 'http://www.onet.pl', 'access-control-allow-methods': 'GET,POST,HEAD,OPTIONS', 'access-control-max-age': '60', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 0cef334729aed841ca9f130c177beebb.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'FRA60-P2', 'X-Amz-Cf-Id': 'jncogISojoetBVjePv9dFEGzo9AKL67yM471rhGEycQkIPeJGdOm2Q=='}

# %%
pprint(r.headers)
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '172554', 'Connection': 'keep-alive', 'Server': 'Ring Publishing - Accelerator', 'Date': 'Wed, 03 Nov 2021 18:38:28 GMT', 'Vary': 'Accept-Encoding, user-agent', 'content-encoding': 'gzip', 'set-cookie': 'aureus-cache-key-onet-film=1747422596; domain=www.onet.pl; Max-Age=3599; Expires=Wed, 03-Nov-2021 19:38:27 GMT, aureus-browser-cache="86eNxjWyId5uc8wMi0Lz3Jepu0DLdMYN/smweXV5HCCIkqLH5vu+ScFXNyB3tVByu8rIwo9TtaoD7kLV11xDeHBQfPt2vqvHKR6sW8uFoZpmMyy7wPcNzTL5pFYfqilP2YM0fjxr8IWN+7sNIyx5IQ=="; Version=1; Domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-oferty2=-1314043481; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-oferty3=1218670026; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-podroze=-2101885636; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-sport_gql=-170008283; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-moto=-346568912; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-noizz=1660533013; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-gamesonline=600672838; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-breakingNews=-1556444008; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-biznes=-932536936; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-technologie=1494516036; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-vod=-1542607624; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-inspiracje=-1381637078; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-paid_promo=-1700698976; domain=www.onet.pl; Max-Age=3599; Expires=Wed, 03-Nov-2021 19:38:27 GMT, aureus-cache-key-onet-wiadomosci_gql=769283373; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-lamoda=-1494515482; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, aureus-cache-key-onet-impnews=1566437523; domain=www.onet.pl; Max-Age=3600; Expires=Wed, 03-Nov-2021 19:38:28 GMT, acc_segment=41; Path=/; Max-Age=604800; Secure', 'cache-control': 'no-cache', 'link': '<https://ocdn.eu>; rel=preconnect, <https://events.ocdn.eu>; rel=preconnect', 'etag': '"172554-7ac9154c187164f1"', 'x-dns-prefetch-control': 'off', 'x-frame-options': 'SAMEORIGIN', 'strict-transport-security': 'max-age=0', 'x-download-options': 'noopen', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'content-security-policy-report-only': 'block-all-mixed-content; report-uri https://events.ocdn.eu/v2/csp-report?_ac=events&_fv=www.onet.pl::BPROD_3_0_REST', 'access-control-allow-origin': 'http://www.onet.pl', 'access-control-allow-methods': 'GET,POST,HEAD,OPTIONS', 'access-control-max-age': '60', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 0cef334729aed841ca9f130c177beebb.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'FRA60-P2', 'X-Amz-Cf-Id': 'jncogISojoetBVjePv9dFEGzo9AKL67yM471rhGEycQkIPeJGdOm2Q=='}

# %%
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
url = 'https://mate-django-backend.herokuapp.com/api/v1/category/'
r = requests.get(url)

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
[el for el in dir(r) if '_' not in el]
# Out:
# ['close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raw',
#  'reason',
#  'request',
#  'text',
#  'url']

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '[{"pk":1,"name":"Przyprawy"},{"pk":2,"name":"Bakalie"},{"pk":3,"name":"Nabiał"},{"pk":4,"name":"Warzywa"},{"pk":5,"name":"Owoce"},{"pk":6,"name":"Owoce morza"},{"pk":7,"name":"Owoce morza"},{"pk":8,"name":"egzotyczne"},{"pk":9,"name":"Owoce morza"},{"pk":11,"name":"egzotyczne 23344"},{"pk":12,"name":"Warzywa"},{"pk":13,"name":"Samochody"},{"pk":14,"name":"Samochody"},{"pk":15,"name":"Bolidy"},{"pk":16,"name":"Bolidy"},{"pk":17,"name":"Bolidy"},{"pk":18,"name":"Narzedzia"},{"pk":19,"name":"Narzedzia"},{"pk":20,"name":"Narzedzia"},{"pk":21,"name":"Rowery"},{"pk":22,"name":"statki"},{"pk":23,"name":"statki"},{"pk":24,"name":"statki"},{"pk":25,"name":"statki"},{"pk":26,"name":"statki"},{"pk":27,"name":"statki"},{"pk":28,"name":"Statki"},{"pk":29,"name":"Statki"},{"pk":30,"name":"Statki"},{"pk":31,"name":"Statki"},{"pk":32,"name":"Statki"},{"pk":33,"name":"Statki"},{"pk":34,"name":"Statki"},{"pk":35,"name":"Statki"},{"pk":36,"name":"Statki"},{"pk":37,"name":"Statki"},{"pk":38,"name":"Statki"},{"pk":39,"name":"Statki"},{"pk":40,"name":"Przyprawy"},{"pk":41,"name":"Przyprawy"},{"pk":42,"name":"Przyprawy"},{"pk":43,"name":"Przyprawy"},{"pk":44,"name":"Przyprawy"},{"pk":45,"name":"Przyprawy"},{"pk":46,"name":"Przyprawy"},{"pk":47,"name":"Przyprawy"},{"pk":48,"name":"Przyprawy"},{"pk":49,"name":"Przyprawy"},{"pk":50,"name":"Bakalie"},{"pk":51,"name":"Bakalie"},{"pk":52,"name":"Bakalie"},{"pk":53,"name":"Bakalie"},{"pk":54,"name":"Bakalie"},{"pk":55,"name":"Bakalie"},{"pk":56,"name":"Bakalie"},{"pk":57,"name":"Bakalie"},{"pk":58,"name":"Bakalie"},{"pk":59,"name":"Bakalie"},{"pk":60,"name":"Bakalie"},{"pk":61,"name":"Bakalie"},{"pk":62,"name":"Bakalie"},{"pk":63,"name":"Bakalie"},{"pk":64,"name":"Ferrari"},{"pk":65,"name":"Bakalie"},{"pk":66,"name":"Ferrari"},{"pk":67,"name":"Narzedzia"},{"pk":68,"name":"Narzedzia"},{"pk":69,"name":"Arbuzy"},{"pk":70,"name":"owoce"},{"pk":71,"name":"Arbuzy"},{"pk":72,"name":"owoce"},{"pk":73,"name":"Arbuzy"},{"pk":74,"name":"owoce"},{"pk":75,"name":"Narzedzia"},{"pk":76,"name":"Bolid"},{"pk":78,"name":"Owoce morza 23"},{"pk":79,"name":"Owoce morza 23"},{"pk":80,"name":"egzotyczne"}]'

# %%
r.json()
# Out:
# [{'pk': 1, 'name': 'Przyprawy'},
#  {'pk': 2, 'name': 'Bakalie'},
#  {'pk': 3, 'name': 'Nabiał'},
#  {'pk': 4, 'name': 'Warzywa'},
#  {'pk': 5, 'name': 'Owoce'},
#  {'pk': 6, 'name': 'Owoce morza'},
#  {'pk': 7, 'name': 'Owoce morza'},
#  {'pk': 8, 'name': 'egzotyczne'},
#  {'pk': 9, 'name': 'Owoce morza'},
#  {'pk': 11, 'name': 'egzotyczne 23344'},
#  {'pk': 12, 'name': 'Warzywa'},
#  {'pk': 13, 'name': 'Samochody'},
#  {'pk': 14, 'name': 'Samochody'},
#  {'pk': 15, 'name': 'Bolidy'},
#  {'pk': 16, 'name': 'Bolidy'},
#  {'pk': 17, 'name': 'Bolidy'},
#  {'pk': 18, 'name': 'Narzedzia'},
#  {'pk': 19, 'name': 'Narzedzia'},
#  {'pk': 20, 'name': 'Narzedzia'},
#  {'pk': 21, 'name': 'Rowery'},
#  {'pk': 22, 'name': 'statki'},
#  {'pk': 23, 'name': 'statki'},
#  {'pk': 24, 'name': 'statki'},
#  {'pk': 25, 'name': 'statki'},
#  {'pk': 26, 'name': 'statki'},
#  {'pk': 27, 'name': 'statki'},
#  {'pk': 28, 'name': 'Statki'},
#  {'pk': 29, 'name': 'Statki'},
#  {'pk': 30, 'name': 'Statki'},
#  {'pk': 31, 'name': 'Statki'},
#  {'pk': 32, 'name': 'Statki'},
#  {'pk': 33, 'name': 'Statki'},
#  {'pk': 34, 'name': 'Statki'},
#  {'pk': 35, 'name': 'Statki'},
#  {'pk': 36, 'name': 'Statki'},
#  {'pk': 37, 'name': 'Statki'},
#  {'pk': 38, 'name': 'Statki'},
#  {'pk': 39, 'name': 'Statki'},
#  {'pk': 40, 'name': 'Przyprawy'},
#  {'pk': 41, 'name': 'Przyprawy'},
#  {'pk': 42, 'name': 'Przyprawy'},
#  {'pk': 43, 'name': 'Przyprawy'},
#  {'pk': 44, 'name': 'Przyprawy'},
#  {'pk': 45, 'name': 'Przyprawy'},
#  {'pk': 46, 'name': 'Przyprawy'},
#  {'pk': 47, 'name': 'Przyprawy'},
#  {'pk': 48, 'name': 'Przyprawy'},
#  {'pk': 49, 'name': 'Przyprawy'},
#  {'pk': 50, 'name': 'Bakalie'},
#  {'pk': 51, 'name': 'Bakalie'},
#  {'pk': 52, 'name': 'Bakalie'},
#  {'pk': 53, 'name': 'Bakalie'},
#  {'pk': 54, 'name': 'Bakalie'},
#  {'pk': 55, 'name': 'Bakalie'},
#  {'pk': 56, 'name': 'Bakalie'},
#  {'pk': 57, 'name': 'Bakalie'},
#  {'pk': 58, 'name': 'Bakalie'},
#  {'pk': 59, 'name': 'Bakalie'},
#  {'pk': 60, 'name': 'Bakalie'},
#  {'pk': 61, 'name': 'Bakalie'},
#  {'pk': 62, 'name': 'Bakalie'},
#  {'pk': 63, 'name': 'Bakalie'},
#  {'pk': 64, 'name': 'Ferrari'},
#  {'pk': 65, 'name': 'Bakalie'},
#  {'pk': 66, 'name': 'Ferrari'},
#  {'pk': 67, 'name': 'Narzedzia'},
#  {'pk': 68, 'name': 'Narzedzia'},
#  {'pk': 69, 'name': 'Arbuzy'},
#  {'pk': 70, 'name': 'owoce'},
#  {'pk': 71, 'name': 'Arbuzy'},
#  {'pk': 72, 'name': 'owoce'},
#  {'pk': 73, 'name': 'Arbuzy'},
#  {'pk': 74, 'name': 'owoce'},
#  {'pk': 75, 'name': 'Narzedzia'},
#  {'pk': 76, 'name': 'Bolid'},
#  {'pk': 78, 'name': 'Owoce morza 23'},
#  {'pk': 79, 'name': 'Owoce morza 23'},
#  {'pk': 80, 'name': 'egzotyczne'}]

# %%
"""
Sprawdzić później wszystkie metody i pola
"""
type(r.content)
# Out:
# bytes

# %%
# POST
r = requests.get(url)
payload = {'name': 'egzotyczne'}
r = requests.post(url, json=payload)

# %%
r.status_code
# Out:
# 201
